# %% [markdown]
# 開啟分析資料檔，並進行資料預處理

# %%
import pandas as pd
df=pd.read_excel('loan3(na).xlsx')

# %%
df.head(5)
#loan=2表示違約
# Out:
#    loan  Industry_type  Company_type  Beginning_time  Collateral  \
# 0   1.0              1           1.0               4           4
# 1   1.0              2           1.0               2           3
# 2   1.0              1           1.0               3           3
# 3   1.0              2           1.0               4           1
# 4   1.0              1           1.0               3           1
#
#    Bank_relationship  Capital_increase  Age  Education  Credit
# 0                  1                 4    3          2       2
# 1                  2                 3    4          3       2
# 2                  1                 4    3          4       1
# 3                  1                 4    3          4       2
# 4                  1                 3    2          3       2

# %%
df.isnull().any() #尋找空值變數
# Out:
# loan                  True
# Industry_type        False
# Company_type          True
# Beginning_time       False
# Collateral           False
# Bank_relationship    False
# Capital_increase     False
# Age                  False
# Education            False
# Credit               False
# dtype: bool

# %%
df1=df.dropna()
X=df1[['Industry_type','Company_type','Beginning_time','Bank_relationship','Capital_increase','Age','Education','Credit']]
y=df1['loan']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=5)

# %% [markdown]
# 判別分析語法

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
LDA = LinearDiscriminantAnalysis()
LDA.fit(X_train,y_train)
# Out:
# LinearDiscriminantAnalysis()

# %%
X_train.columns
# Out:
# Index(['Industry_type', 'Company_type', 'Beginning_time', 'Bank_relationship',
#        'Capital_increase', 'Age', 'Education', 'Credit'],
#       dtype='object')

# %%
#取得截距。如果公式是y=a+bx，a即是截距
print(LDA.intercept_)
print(LDA.coef_)
# Out:
# [8.15807178]
# [[ 7.52448804e-01 -9.38387417e-01  2.95015190e-03  2.41971753e+00
#   -1.50150096e-01 -1.23770458e+00  2.95980948e-01 -5.76867885e+00]]

# %% [markdown]
# #計算模式績效:
# 1.列出混淆矩陣(confusion matrix)
# 2.計算模式衡量指標(accuracy、precision、recall、f1-score等)

# %%
#列印訓練完成之模式的混淆矩陣(confusion matrix)以及模式衡量指標
from sklearn.metrics import classification_report,confusion_matrix
LDA_tpred= LDA.predict(X_train)
print(confusion_matrix(y_train,LDA_tpred))
print("======================================================\n")
print(classification_report(y_train,LDA_tpred))
# Out:
# [[111   5]
#  [ 14  23]]
# ======================================================
#
#               precision    recall  f1-score   support
#
#          1.0       0.89      0.96      0.92       116
#          2.0       0.82      0.62      0.71        37
#
#     accuracy                           0.88       153
#    macro avg       0.85      0.79      0.81       153
# weighted avg       0.87      0.88      0.87       153

# %%
#列印測試資料的混淆矩陣(confusion matrix)以及模式衡量指標
LDA_pred= LDA.predict(X_test)
print(confusion_matrix(y_test,LDA_pred))
print("======================================================\n")
print(classification_report(y_test,LDA_pred))
# Out:
# [[34  2]
#  [ 3 12]]
# ======================================================
#
#               precision    recall  f1-score   support
#
#          1.0       0.92      0.94      0.93        36
#          2.0       0.86      0.80      0.83        15
#
#     accuracy                           0.90        51
#    macro avg       0.89      0.87      0.88        51
# weighted avg       0.90      0.90      0.90        51

# %% [markdown]
# #預測模式之應用:輸入特徵，提供預測之結果
# 1.分類結果
# 2.預測其隸屬不同類別之機率

# %%
#輸入自變數數值，計算所預測之分類結果
LDA.predict([[1,1,1,3,1,4,3,1]])
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   "X does not have valid feature names, but"
# array([2.])

# %%
#輸入自變數數值，計算所預測不同類別發生機率
LDA.predict_proba([[1,1,1,3,1,4,3,1]])
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   "X does not have valid feature names, but"
# array([[0.005207, 0.994793]])

# %%
#同時輸入兩組自變數數值，計算所預測之分類結果
LDA.predict([[1,1,1,3,1,4,3,2],[1,1,1,3,1,4,3,1]])
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   "X does not have valid feature names, but"
# array([1., 2.])

# %%
#同時輸入兩組自變數數值，計算所預測不同類別發生機率
LDA.predict_proba([[1,1,1,3,1,4,3,2],[1,1,1,3,1,4,3,1]])
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LinearDiscriminantAnalysis was fitted with feature names
#   "X does not have valid feature names, but"
# array([[0.62624645, 0.37375355],
#        [0.005207  , 0.994793  ]])

# %% [markdown]
# # 練習一：
# 請以nba2.xlsx之資料，以1Q, 2Q, 3Q建立球賽勝負(W/L)之LDA預測模式，並說明你預測模型的準確度。
#
# 註：1.1Q, 2Q, 3Q分別表前三節得分
#    2.球賽勝負(W/L):0表敗，1表勝

# %% [markdown]
# # 作業：
# 請利用boston_house(type).xlsx檔案中的指標來預測boston house的房價高低(Price Type)，分析後請說明預測分析之結果。
#
# 註：
# 1.資料與預測指標說明如附檔。
# 2.Price Type:1表單位房價低於20，2表單位房價高於20。
